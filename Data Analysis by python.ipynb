# %%
# !pip install pandas==1.3.4 numpy==1.21.4 seaborn==0.9.0 matplotlib==3.5.0 scikit-learn==0.20.1
# Out:
# Collecting pandas==1.3.4
#   Downloading pandas-1.3.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 68.3 MB/s eta 0:00:0000:010:01
# Collecting numpy==1.21.4
#   Downloading numpy-1.21.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 75.8 MB/s eta 0:00:0000:0100:01
# Collecting seaborn==0.9.0
#   Downloading seaborn-0.9.0-py3-none-any.whl (208 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.1/208.1 kB 26.3 MB/s eta 0:00:00
# Collecting matplotlib==3.5.0
#   Downloading matplotlib-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 59.0 MB/s eta 0:00:0000:010:01m
# Collecting scikit-learn==0.20.1
#   Downloading scikit-learn-0.20.1.tar.gz (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 37.0 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from pandas==1.3.4) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from pandas==1.3.4) (2022.7)
# Requirement already satisfied: scipy>=0.14.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from seaborn==0.9.0) (1.10.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from matplotlib==3.5.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from matplotlib==3.5.0) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from matplotlib==3.5.0) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from matplotlib==3.5.0) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from matplotlib==3.5.0) (10.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from matplotlib==3.5.0) (3.0.9)
# Collecting setuptools-scm>=4 (from matplotlib==3.5.0)
#   Downloading setuptools_scm-8.0.4-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from python-dateutil>=2.7.3->pandas==1.3.4) (1.16.0)
# Requirement already satisfied: setuptools in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from setuptools-scm>=4->matplotlib==3.5.0) (65.6.3)
# Requirement already satisfied: typing-extensions in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from setuptools-scm>=4->matplotlib==3.5.0) (4.4.0)
# Requirement already satisfied: tomli>=1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from setuptools-scm>=4->matplotlib==3.5.0) (2.0.1)
# Downloading setuptools_scm-8.0.4-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 kB 5.8 MB/s eta 0:00:00
# Building wheels for collected packages: scikit-learn
#   Building wheel for scikit-learn (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [2086 lines of output]
#       Partial import of sklearn during the build process.
#       /tmp/wsuser/pip-install-zm05izuo/scikit-learn_63307558bfff4e5290ccd0d82e490222/setup.py:242: DeprecationWarning:
#
#         `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#         of the deprecation of `distutils` itself. It will be removed for
#         Python >= 3.12. For older Python versions it will remain present.
#         It is recommended to use `setuptools < 60.0` for those Python versions.
#         For more details, see:
#           https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#         from numpy.distutils.core import setup
#       INFO: blas_opt_info:
#       INFO: blas_armpl_info:
#       INFO: customize UnixCCompiler
#       INFO:   libraries armpl_lp64_mp not found in ['/opt/conda/envs/Python-RT23.1/lib', '/usr/local/lib64', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: blas_mkl_info:
#       INFO:   libraries mkl_rt not found in ['/opt/conda/envs/Python-RT23.1/lib', '/usr/local/lib64', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: blis_info:
#       INFO:   libraries blis not found in ['/opt/conda/envs/Python-RT23.1/lib', '/usr/local/lib64', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: openblas_info:
#       INFO: C compiler: gcc -pthread -B /opt/conda/envs/Python-RT23.1/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/envs/Python-RT23.1/include -fPIC -O2 -isystem /opt/conda/envs/Python-RT23.1/include -fPIC
#
#       creating /tmp/wsuser/tmpwismu77z/tmp
#       creating /tmp/wsuser/tmpwismu77z/tmp/wsuser
#       creating /tmp/wsuser/tmpwismu77z/tmp/wsuser/tmpwismu77z
#       INFO: compile options: '-c'
#       INFO: gcc: /tmp/wsuser/tmpwismu77z/source.c
#       INFO: gcc -pthread -B /opt/conda/envs/Python-RT23.1/compiler_compat /tmp/wsuser/tmpwismu77z/tmp/wsuser/tmpwismu77z/source.o -L/opt/conda/envs/Python-RT23.1/lib -lopenblas -o /tmp/wsuser/tmpwismu77z/a.out
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: warning: libm.so.6, needed by /opt/conda/envs/Python-RT23.1/lib/libopenblas.so, not found (try using -rpath or -rpath-link)
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: warning: libquadmath.so.0, needed by /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5, not found (try using -rpath or -rpath-link)
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: warning: libdl.so.2, needed by /opt/conda/envs/Python-RT23.1/lib/./libgomp.so.1, not found (try using -rpath or -rpath-link)
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `atanh@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `sinhq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `acos@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `sin@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `cabsl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `asinl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `asinh@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `exp@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `sincosf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `atanl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `fmal@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `log10l@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `erfcq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `acosq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `asin@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `tanq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `csin@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgomp.so.1: undefined reference to `dlsym@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `jnq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `atan@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `roundl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `jnf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `strtoflt128@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgomp.so.1: undefined reference to `dlerror@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `fmod@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `atan2q@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `nanq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `csqrt@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `sinl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `cosl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `atan2@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `roundf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `ccosf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `expl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `expq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `clogf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `cabs@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `clog@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `log@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `cexpq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `cabsf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `jnl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `atanq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `fmaf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `jn@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `atanf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `atanhq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `csinf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `clogl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `lroundq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `truncq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `csqrtl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `tanl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `fmodl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `ccos@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `csinq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `sqrtl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `ccosl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `atan2l@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `cos@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `coshl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `cosh@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `sinhf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `csqrtq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `coshq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `acosh@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `ynq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `asinhl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `ynf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `yn@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `tanhl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `fma@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `ccosq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `powf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `asinq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `tanh@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `quadmath_snprintf@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgomp.so.1: undefined reference to `dlclose@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `tanhq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `sinf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `fmodf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `pow@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `asinhf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `acosl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `fmaq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `acoshl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `coshf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `clogq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `atan2f@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `roundq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `expf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `lround@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `csqrtf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `tanf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `logl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `fmodq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `round@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgomp.so.1: undefined reference to `dlopen@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `copysignq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `fabsq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `sqrtq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `log10@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `asinf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `sinhl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `sqrtf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `atanhf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `log10q@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `logf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `cosf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `sinh@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `tan@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `log10f@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `cosq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `asinhq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `lroundl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `acoshf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `logq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `cexp@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `acosf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `sqrt@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `csinl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `acoshq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `sincos@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `lroundf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `ynl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `atanhl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `cexpl@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `tanhf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `sinq@QUADMATH_1.0'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/libopenblas.so: undefined reference to `cexpf@GLIBC_2.2.5'
#       /opt/conda/envs/Python-RT23.1/compiler_compat/ld: /opt/conda/envs/Python-RT23.1/lib/./libgfortran.so.5: undefined reference to `cabsq@QUADMATH_1.0'
#       collect2: error: ld returned 1 exit status
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: accelerate_info:
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_3_10_blas_threads_info:
#       INFO: Setting PTATLAS=ATLAS
#       INFO:   libraries tatlas not found in ['/opt/conda/envs/Python-RT23.1/lib', '/usr/local/lib64', '/usr/local/lib', '/usr/lib64/sse2', '/usr/lib64', '/usr/lib/sse2', '/usr/lib', '/usr/lib/sse2', '/usr/lib/']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_3_10_blas_info:
#       INFO:   libraries satlas not found in ['/opt/conda/envs/Python-RT23.1/lib', '/usr/local/lib64', '/usr/local/lib', '/usr/lib64/sse2', '/usr/lib64', '/usr/lib/sse2', '/usr/lib', '/usr/lib/sse2', '/usr/lib/']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_blas_threads_info:
#       INFO: Setting PTATLAS=ATLAS
#       INFO:   libraries ptf77blas,ptcblas,atlas not found in ['/opt/conda/envs/Python-RT23.1/lib', '/usr/local/lib64', '/usr/local/lib', '/usr/lib64/sse2', '/usr/lib64', '/usr/lib/sse2', '/usr/lib', '/usr/lib/sse2', '/usr/lib/']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_blas_info:
#       INFO:   libraries f77blas,cblas,atlas not found in ['/opt/conda/envs/Python-RT23.1/lib', '/usr/local/lib64', '/usr/local/lib', '/usr/lib64/sse2', '/usr/lib64', '/usr/lib/sse2', '/usr/lib', '/usr/lib/sse2', '/usr/lib/']
#       INFO:   NOT AVAILABLE
#       INFO:
#       /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages/numpy/distutils/system_info.py:2077: UserWarning:
#           Optimized (vendor) Blas libraries are not found.
#           Falls back to netlib Blas library which has worse performance.
#           A better performance should be easily gained by switching
#           Blas library.
#         if self._calc_info(blas):
#       INFO: blas_info:
#       INFO: C compiler: gcc -pthread -B /opt/conda/envs/Python-RT23.1/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/envs/Python-RT23.1/include -fPIC -O2 -isystem /opt/conda/envs/Python-RT23.1/include -fPIC
#
#       creating /tmp/wsuser/tmpbh51ha8x/tmp
#       creating /tmp/wsuser/tmpbh51ha8x/tmp/wsuser
#       creating /tmp/wsuser/tmpbh51ha8x/tmp/wsuser/tmpbh51ha8x
#       INFO: compile options: '-I/usr/local/include -I/opt/conda/envs/Python-RT23.1/include -c'
#       INFO: gcc: /tmp/wsuser/tmpbh51ha8x/source.c
#       /tmp/wsuser/tmpbh51ha8x/source.c:1:10: fatal error: cblas.h: No such file or directory
#        #include <cblas.h>
#                 ^~~~~~~~~
#       compilation terminated.
#       INFO:   FOUND:
#       INFO:     libraries = ['blas', 'blas']
#       INFO:     library_dirs = ['/opt/conda/envs/Python-RT23.1/lib']
#       INFO:     include_dirs = ['/usr/local/include', '/opt/conda/envs/Python-RT23.1/include']
#       INFO:
#       INFO:   FOUND:
#       INFO:     define_macros = [('NO_ATLAS_INFO', 1)]
#       INFO:     libraries = ['blas', 'blas']
#       INFO:     library_dirs = ['/opt/conda/envs/Python-RT23.1/lib']
#       INFO:     include_dirs = ['/usr/local/include', '/opt/conda/envs/Python-RT23.1/include']
#       INFO:
#       /tmp/wsuser/pip-install-zm05izuo/scikit-learn_63307558bfff4e5290ccd0d82e490222/sklearn/setup.py:73: UserWarning:
#           Blas (http://www.netlib.org/blas/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [blas]) or by setting
#           the BLAS environment variable.
#         warnings.warn(BlasNotFoundError.__doc__)
#       running bdist_wheel
#       running build
#       running config_cc
#       INFO: unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#       running config_fc
#       INFO: unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#       running build_src
#       INFO: build_src
#       INFO: building library "libsvm-skl" sources
#       INFO: building library "cblas" sources
#       INFO: building extension "sklearn.__check_build._check_build" sources
#       INFO: building extension "sklearn.cluster._dbscan_inner" sources
#       INFO: building extension "sklearn.cluster._hierarchical" sources
#       INFO: building extension "sklearn.cluster._k_means_elkan" sources
#       INFO: building extension "sklearn.cluster._k_means" sources
#       INFO: building extension "sklearn.datasets._svmlight_format" sources
#       INFO: building extension "sklearn.decomposition._online_lda" sources
#       INFO: building extension "sklearn.decomposition.cdnmf_fast" sources
#       INFO: building extension "sklearn.ensemble._gradient_boosting" sources
#       INFO: building extension "sklearn.feature_extraction._hashing" sources
#       INFO: building extension "sklearn.manifold._utils" sources
#       INFO: building extension "sklearn.manifold._barnes_hut_tsne" sources
#       INFO: building extension "sklearn.metrics.cluster.expected_mutual_info_fast" sources
#       INFO: building extension "sklearn.metrics.pairwise_fast" sources
#       INFO: building extension "sklearn.neighbors.ball_tree" sources
#       INFO: building extension "sklearn.neighbors.kd_tree" sources
#       INFO: building extension "sklearn.neighbors.dist_metrics" sources
#       INFO: building extension "sklearn.neighbors.typedefs" sources
#       INFO: building extension "sklearn.neighbors.quad_tree" sources
#       INFO: building extension "sklearn.tree._tree" sources
#       INFO: building extension "sklearn.tree._splitter" sources
#       INFO: building extension "sklearn.tree._criterion" sources
#       INFO: building extension "sklearn.tree._utils" sources
#       INFO: building extension "sklearn.svm.libsvm" sources
#       INFO: building extension "sklearn.svm.liblinear" sources
#       INFO: building extension "sklearn.svm.libsvm_sparse" sources
#       INFO: building extension "sklearn._isotonic" sources
#       INFO: building extension "sklearn.linear_model.cd_fast" sources
#       INFO: building extension "sklearn.linear_model.sgd_fast" sources
#       INFO: building extension "sklearn.linear_model.sag_fast" sources
#       INFO: building extension "sklearn.utils.sparsefuncs_fast" sources
#       INFO: building extension "sklearn.utils.arrayfuncs" sources
#       INFO: building extension "sklearn.utils.murmurhash" sources
#       INFO: building extension "sklearn.utils.lgamma" sources
#       INFO: building extension "sklearn.utils.graph_shortest_path" sources
#       INFO: building extension "sklearn.utils.fast_dict" sources
#       INFO: building extension "sklearn.utils.seq_dataset" sources
#       INFO: building extension "sklearn.utils.weight_vector" sources
#       INFO: building extension "sklearn.utils._random" sources
#       INFO: building extension "sklearn.utils._logistic_sigmoid" sources
#       INFO: building data_files sources
#       INFO: build_src: building npy-pkg config files
#       /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build_py
#       creating build
#       creating build/lib.linux-x86_64-cpython-310
#       creating build/lib.linux-x86_64-cpython-310/sklearn
#       copying sklearn/exceptions.py -> build/lib.linux-x86_64-cpython-310/sklearn
#       copying sklearn/isotonic.py -> build/lib.linux-x86_64-cpython-310/sklearn
#       copying sklearn/naive_bayes.py -> build/lib.linux-x86_64-cpython-310/sklearn
#       copying sklearn/calibration.py -> build/lib.linux-x86_64-cpython-310/sklearn
#       copying sklearn/kernel_ridge.py -> build/lib.linux-x86_64-cpython-310/sklearn
#       copying sklearn/setup.py -> build/lib.linux-x86_64-cpython-310/sklearn
#       copying sklearn/kernel_approximation.py -> build/lib.linux-x86_64-cpython-310/sklearn
#       copying sklearn/impute.py -> build/lib.linux-x86_64-cpython-310/sklearn
#       copying sklearn/multiclass.py -> build/lib.linux-x86_64-cpython-310/sklearn
#       copying sklearn/multioutput.py -> build/lib.linux-x86_64-cpython-310/sklearn
#       copying sklearn/random_projection.py -> build/lib.linux-x86_64-cpython-310/sklearn
#       copying sklearn/base.py -> build/lib.linux-x86_64-cpython-310/sklearn
#       copying sklearn/pipeline.py -> build/lib.linux-x86_64-cpython-310/sklearn
#       copying sklearn/dummy.py -> build/lib.linux-x86_64-cpython-310/sklearn
#       copying sklearn/_config.py -> build/lib.linux-x86_64-cpython-310/sklearn
#       copying sklearn/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn
#       copying sklearn/discriminant_analysis.py -> build/lib.linux-x86_64-cpython-310/sklearn
#       creating build/lib.linux-x86_64-cpython-310/sklearn/__check_build
#       copying sklearn/__check_build/setup.py -> build/lib.linux-x86_64-cpython-310/sklearn/__check_build
#       copying sklearn/__check_build/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/__check_build
#       creating build/lib.linux-x86_64-cpython-310/sklearn/_build_utils
#       copying sklearn/_build_utils/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/_build_utils
#       creating build/lib.linux-x86_64-cpython-310/sklearn/compose
#       copying sklearn/compose/_column_transformer.py -> build/lib.linux-x86_64-cpython-310/sklearn/compose
#       copying sklearn/compose/_target.py -> build/lib.linux-x86_64-cpython-310/sklearn/compose
#       copying sklearn/compose/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/compose
#       creating build/lib.linux-x86_64-cpython-310/sklearn/compose/tests
#       copying sklearn/compose/tests/test_column_transformer.py -> build/lib.linux-x86_64-cpython-310/sklearn/compose/tests
#       copying sklearn/compose/tests/test_target.py -> build/lib.linux-x86_64-cpython-310/sklearn/compose/tests
#       copying sklearn/compose/tests/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/compose/tests
#       creating build/lib.linux-x86_64-cpython-310/sklearn/covariance
#       copying sklearn/covariance/shrunk_covariance_.py -> build/lib.linux-x86_64-cpython-310/sklearn/covariance
#       copying sklearn/covariance/elliptic_envelope.py -> build/lib.linux-x86_64-cpython-310/sklearn/covariance
#       copying sklearn/covariance/empirical_covariance_.py -> build/lib.linux-x86_64-cpython-310/sklearn/covariance
#       copying sklearn/covariance/graph_lasso_.py -> build/lib.linux-x86_64-cpython-310/sklearn/covariance
#       copying sklearn/covariance/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/covariance
#       copying sklearn/covariance/robust_covariance.py -> build/lib.linux-x86_64-cpython-310/sklearn/covariance
#       creating build/lib.linux-x86_64-cpython-310/sklearn/covariance/tests
#       copying sklearn/covariance/tests/test_covariance.py -> build/lib.linux-x86_64-cpython-310/sklearn/covariance/tests
#       copying sklearn/covariance/tests/test_elliptic_envelope.py -> build/lib.linux-x86_64-cpython-310/sklearn/covariance/tests
#       copying sklearn/covariance/tests/test_graph_lasso.py -> build/lib.linux-x86_64-cpython-310/sklearn/covariance/tests
#       copying sklearn/covariance/tests/test_graphical_lasso.py -> build/lib.linux-x86_64-cpython-310/sklearn/covariance/tests
#       copying sklearn/covariance/tests/test_robust_covariance.py -> build/lib.linux-x86_64-cpython-310/sklearn/covariance/tests
#       copying sklearn/covariance/tests/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/covariance/tests
#       creating build/lib.linux-x86_64-cpython-310/sklearn/cross_decomposition
#       copying sklearn/cross_decomposition/cca_.py -> build/lib.linux-x86_64-cpython-310/sklearn/cross_decomposition
#       copying sklearn/cross_decomposition/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/cross_decomposition
#       copying sklearn/cross_decomposition/pls_.py -> build/lib.linux-x86_64-cpython-310/sklearn/cross_decomposition
#       creating build/lib.linux-x86_64-cpython-310/sklearn/cross_decomposition/tests
#       copying sklearn/cross_decomposition/tests/test_pls.py -> build/lib.linux-x86_64-cpython-310/sklearn/cross_decomposition/tests
#       copying sklearn/cross_decomposition/tests/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/cross_decomposition/tests
#       creating build/lib.linux-x86_64-cpython-310/sklearn/feature_selection
#       copying sklearn/feature_selection/from_model.py -> build/lib.linux-x86_64-cpython-310/sklearn/feature_selection
#       copying sklearn/feature_selection/mutual_info_.py -> build/lib.linux-x86_64-cpython-310/sklearn/feature_selection
#       copying sklearn/feature_selection/univariate_selection.py -> build/lib.linux-x86_64-cpython-310/sklearn/feature_selection
#       copying sklearn/feature_selection/base.py -> build/lib.linux-x86_64-cpython-310/sklearn/feature_selection
#       copying sklearn/feature_selection/variance_threshold.py -> build/lib.linux-x86_64-cpython-310/sklearn/feature_selection
#       copying sklearn/feature_selection/rfe.py -> build/lib.linux-x86_64-cpython-310/sklearn/feature_selection
#       copying sklearn/feature_selection/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/feature_selection
#       creating build/lib.linux-x86_64-cpython-310/sklearn/feature_selection/tests
#       copying sklearn/feature_selection/tests/test_chi2.py -> build/lib.linux-x86_64-cpython-310/sklearn/feature_selection/tests
#       copying sklearn/feature_selection/tests/test_variance_threshold.py -> build/lib.linux-x86_64-cpython-310/sklearn/feature_selection/tests
#       copying sklearn/feature_selection/tests/test_mutual_info.py -> build/lib.linux-x86_64-cpython-310/sklearn/feature_selection/tests
#       copying sklearn/feature_selection/tests/test_base.py -> build/lib.linux-x86_64-cpython-310/sklearn/feature_selection/tests
#       copying sklearn/feature_selection/tests/test_rfe.py -> build/lib.linux-x86_64-cpython-310/sklearn/feature_selection/tests
#       copying sklearn/feature_selection/tests/test_feature_select.py -> build/lib.linux-x86_64-cpython-310/sklearn/feature_selection/tests
#       copying sklearn/feature_selection/tests/test_from_model.py -> build/lib.linux-x86_64-cpython-310/sklearn/feature_selection/tests
#       copying sklearn/feature_selection/tests/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/feature_selection/tests
#       creating build/lib.linux-x86_64-cpython-310/sklearn/gaussian_process
#       copying sklearn/gaussian_process/gpc.py -> build/lib.linux-x86_64-cpython-310/sklearn/gaussian_process
#       copying sklearn/gaussian_process/regression_models.py -> build/lib.linux-x86_64-cpython-310/sklearn/gaussian_process
#       copying sklearn/gaussian_process/kernels.py -> build/lib.linux-x86_64-cpython-310/sklearn/gaussian_process
#       copying sklearn/gaussian_process/gpr.py -> build/lib.linux-x86_64-cpython-310/sklearn/gaussian_process
#       copying sklearn/gaussian_process/correlation_models.py -> build/lib.linux-x86_64-cpython-310/sklearn/gaussian_process
#       copying sklearn/gaussian_process/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/gaussian_process
#       creating build/lib.linux-x86_64-cpython-310/sklearn/gaussian_process/tests
#       copying sklearn/gaussian_process/tests/test_gpc.py -> build/lib.linux-x86_64-cpython-310/sklearn/gaussian_process/tests
#       copying sklearn/gaussian_process/tests/test_kernels.py -> build/lib.linux-x86_64-cpython-310/sklearn/gaussian_process/tests
#       copying sklearn/gaussian_process/tests/test_gpr.py -> build/lib.linux-x86_64-cpython-310/sklearn/gaussian_process/tests
#       copying sklearn/gaussian_process/tests/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/gaussian_process/tests
#       creating build/lib.linux-x86_64-cpython-310/sklearn/mixture
#       copying sklearn/mixture/gaussian_mixture.py -> build/lib.linux-x86_64-cpython-310/sklearn/mixture
#       copying sklearn/mixture/base.py -> build/lib.linux-x86_64-cpython-310/sklearn/mixture
#       copying sklearn/mixture/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/mixture
#       copying sklearn/mixture/bayesian_mixture.py -> build/lib.linux-x86_64-cpython-310/sklearn/mixture
#       creating build/lib.linux-x86_64-cpython-310/sklearn/mixture/tests
#       copying sklearn/mixture/tests/test_bayesian_mixture.py -> build/lib.linux-x86_64-cpython-310/sklearn/mixture/tests
#       copying sklearn/mixture/tests/test_mixture.py -> build/lib.linux-x86_64-cpython-310/sklearn/mixture/tests
#       copying sklearn/mixture/tests/test_gaussian_mixture.py -> build/lib.linux-x86_64-cpython-310/sklearn/mixture/tests
#       copying sklearn/mixture/tests/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/mixture/tests
#       creating build/lib.linux-x86_64-cpython-310/sklearn/model_selection
#       copying sklearn/model_selection/_search.py -> build/lib.linux-x86_64-cpython-310/sklearn/model_selection
#       copying sklearn/model_selection/_validation.py -> build/lib.linux-x86_64-cpython-310/sklearn/model_selection
#       copying sklearn/model_selection/_split.py -> build/lib.linux-x86_64-cpython-310/sklearn/model_selection
#       copying sklearn/model_selection/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/model_selection
#       creating build/lib.linux-x86_64-cpython-310/sklearn/model_selection/tests
#       copying sklearn/model_selection/tests/test_search.py -> build/lib.linux-x86_64-cpython-310/sklearn/model_selection/tests
#       copying sklearn/model_selection/tests/test_validation.py -> build/lib.linux-x86_64-cpython-310/sklearn/model_selection/tests
#       copying sklearn/model_selection/tests/common.py -> build/lib.linux-x86_64-cpython-310/sklearn/model_selection/tests
#       copying sklearn/model_selection/tests/test_split.py -> build/lib.linux-x86_64-cpython-310/sklearn/model_selection/tests
#       copying sklearn/model_selection/tests/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/model_selection/tests
#       creating build/lib.linux-x86_64-cpython-310/sklearn/neural_network
#       copying sklearn/neural_network/_base.py -> build/lib.linux-x86_64-cpython-310/sklearn/neural_network
#       copying sklearn/neural_network/_stochastic_optimizers.py -> build/lib.linux-x86_64-cpython-310/sklearn/neural_network
#       copying sklearn/neural_network/rbm.py -> build/lib.linux-x86_64-cpython-310/sklearn/neural_network
#       copying sklearn/neural_network/multilayer_perceptron.py -> build/lib.linux-x86_64-cpython-310/sklearn/neural_network
#       copying sklearn/neural_network/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/neural_network
#       creating build/lib.linux-x86_64-cpython-310/sklearn/neural_network/tests
#       copying sklearn/neural_network/tests/test_mlp.py -> build/lib.linux-x86_64-cpython-310/sklearn/neural_network/tests
#       copying sklearn/neural_network/tests/test_rbm.py -> build/lib.linux-x86_64-cpython-310/sklearn/neural_network/tests
#       copying sklearn/neural_network/tests/test_stochastic_optimizers.py -> build/lib.linux-x86_64-cpython-310/sklearn/neural_network/tests
#       copying sklearn/neural_network/tests/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/neural_network/tests
#       creating build/lib.linux-x86_64-cpython-310/sklearn/preprocessing
#       copying sklearn/preprocessing/imputation.py -> build/lib.linux-x86_64-cpython-310/sklearn/preprocessing
#       copying sklearn/preprocessing/_encoders.py -> build/lib.linux-x86_64-cpython-310/sklearn/preprocessing
#       copying sklearn/preprocessing/_discretization.py -> build/lib.linux-x86_64-cpython-310/sklearn/preprocessing
#       copying sklearn/preprocessing/data.py -> build/lib.linux-x86_64-cpython-310/sklearn/preprocessing
#       copying sklearn/preprocessing/base.py -> build/lib.linux-x86_64-cpython-310/sklearn/preprocessing
#       copying sklearn/preprocessing/label.py -> build/lib.linux-x86_64-cpython-310/sklearn/preprocessing
#       copying sklearn/preprocessing/_function_transformer.py -> build/lib.linux-x86_64-cpython-310/sklearn/preprocessing
#       copying sklearn/preprocessing/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/preprocessing
#       creating build/lib.linux-x86_64-cpython-310/sklearn/preprocessing/tests
#       copying sklearn/preprocessing/tests/test_function_transformer.py -> build/lib.linux-x86_64-cpython-310/sklearn/preprocessing/tests
#       copying sklearn/preprocessing/tests/test_base.py -> build/lib.linux-x86_64-cpython-310/sklearn/preprocessing/tests
#       copying sklearn/preprocessing/tests/test_common.py -> build/lib.linux-x86_64-cpython-310/sklearn/preprocessing/tests
#       copying sklearn/preprocessing/tests/test_imputation.py -> build/lib.linux-x86_64-cpython-310/sklearn/preprocessing/tests
#       copying sklearn/preprocessing/tests/test_discretization.py -> build/lib.linux-x86_64-cpython-310/sklearn/preprocessing/tests
#       copying sklearn/preprocessing/tests/test_label.py -> build/lib.linux-x86_64-cpython-310/sklearn/preprocessing/tests
#       copying sklearn/preprocessing/tests/test_encoders.py -> build/lib.linux-x86_64-cpython-310/sklearn/preprocessing/tests
#       copying sklearn/preprocessing/tests/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/preprocessing/tests
#       copying sklearn/preprocessing/tests/test_data.py -> build/lib.linux-x86_64-cpython-310/sklearn/preprocessing/tests
#       creating build/lib.linux-x86_64-cpython-310/sklearn/semi_supervised
#       copying sklearn/semi_supervised/label_propagation.py -> build/lib.linux-x86_64-cpython-310/sklearn/semi_supervised
#       copying sklearn/semi_supervised/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/semi_supervised
#       creating build/lib.linux-x86_64-cpython-310/sklearn/semi_supervised/tests
#       copying sklearn/semi_supervised/tests/test_label_propagation.py -> build/lib.linux-x86_64-cpython-310/sklearn/semi_supervised/tests
#       copying sklearn/semi_supervised/tests/__init__.py -> build/lib.linux-x86_64-cpython-310/sklearn/semi_supervised/tests
#       creating build/lib.linux-x86_64-cpython-310/sklearn/cluster
# ...
#       /opt/conda/envs/Python-RT23.1/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#        Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                                                    ^~~~~~~~~~~~~~~~~~~
#       /opt/conda/envs/Python-RT23.1/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#        #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                                                                  ^
#       /opt/conda/envs/Python-RT23.1/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               PyUnicode_WSTR_LENGTH(op)))
#               ^~~~~~~~~~~~~~~~~~~~~
#       sklearn/cluster/_hierarchical.cpp:22316:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#                                (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                                  ^~~~~~~~~~~~~~~~~~
#       /opt/conda/envs/Python-RT23.1/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#        static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                                 ^~~~~~~~~~~~~~~~~~~~~~~~~~
#       /opt/conda/envs/Python-RT23.1/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#        #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                                                                  ^
#       /opt/conda/envs/Python-RT23.1/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               PyUnicode_WSTR_LENGTH(op)))
#               ^~~~~~~~~~~~~~~~~~~~~
#       sklearn/cluster/_hierarchical.cpp:22316:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#                                (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                                  ^~~~~~~~~~~~~~~~~~
#       /opt/conda/envs/Python-RT23.1/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#        static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                                 ^~~~~~~~~~~~~~~~~~~~~~~~~~
#       sklearn/cluster/_hierarchical.cpp: In function ‘PyObject* __Pyx_CyFunction_Call(PyObject*, PyObject*, PyObject*)’:
#       sklearn/cluster/_hierarchical.cpp:24411:39: warning: ‘PyObject* PyCFunction_Call(PyObject*, PyObject*, PyObject*)’ is deprecated [-Wdeprecated-declarations]
#         return PyCFunction_Call(func, arg, kw);
#                                              ^
#       In file included from /opt/conda/envs/Python-RT23.1/include/python3.10/Python.h:97,
#                        from sklearn/cluster/_hierarchical.cpp:22:
#       /opt/conda/envs/Python-RT23.1/include/python3.10/methodobject.h:33:43: note: declared here
#        Py_DEPRECATED(3.9) PyAPI_FUNC(PyObject *) PyCFunction_Call(PyObject *, PyObject *, PyObject *);
#                                                  ^~~~~~~~~~~~~~~~
#       sklearn/cluster/_hierarchical.cpp:24411:39: warning: ‘PyObject* PyCFunction_Call(PyObject*, PyObject*, PyObject*)’ is deprecated [-Wdeprecated-declarations]
#         return PyCFunction_Call(func, arg, kw);
#                                              ^
#       In file included from /opt/conda/envs/Python-RT23.1/include/python3.10/Python.h:97,
#                        from sklearn/cluster/_hierarchical.cpp:22:
#       /opt/conda/envs/Python-RT23.1/include/python3.10/methodobject.h:33:43: note: declared here
#        Py_DEPRECATED(3.9) PyAPI_FUNC(PyObject *) PyCFunction_Call(PyObject *, PyObject *, PyObject *);
#                                                  ^~~~~~~~~~~~~~~~
#       sklearn/cluster/_hierarchical.cpp: In function ‘int __pyx_CyFunction_init()’:
#       sklearn/cluster/_hierarchical.cpp:24476:41: warning: ‘PyObject* PyCFunction_Call(PyObject*, PyObject*, PyObject*)’ is deprecated [-Wdeprecated-declarations]
#            __pyx_CyFunctionType_type.tp_call = PyCFunction_Call;
#                                                ^~~~~~~~~~~~~~~~
#       In file included from /opt/conda/envs/Python-RT23.1/include/python3.10/Python.h:97,
#                        from sklearn/cluster/_hierarchical.cpp:22:
#       /opt/conda/envs/Python-RT23.1/include/python3.10/methodobject.h:33:43: note: declared here
#        Py_DEPRECATED(3.9) PyAPI_FUNC(PyObject *) PyCFunction_Call(PyObject *, PyObject *, PyObject *);
#                                                  ^~~~~~~~~~~~~~~~
#       sklearn/cluster/_hierarchical.cpp:24476:41: warning: ‘PyObject* PyCFunction_Call(PyObject*, PyObject*, PyObject*)’ is deprecated [-Wdeprecated-declarations]
#            __pyx_CyFunctionType_type.tp_call = PyCFunction_Call;
#                                                ^~~~~~~~~~~~~~~~
#       In file included from /opt/conda/envs/Python-RT23.1/include/python3.10/Python.h:97,
#                        from sklearn/cluster/_hierarchical.cpp:22:
#       /opt/conda/envs/Python-RT23.1/include/python3.10/methodobject.h:33:43: note: declared here
#        Py_DEPRECATED(3.9) PyAPI_FUNC(PyObject *) PyCFunction_Call(PyObject *, PyObject *, PyObject *);
#                                                  ^~~~~~~~~~~~~~~~
#       sklearn/cluster/_hierarchical.cpp: In function ‘PyObject* __Pyx_decode_c_string(const char*, Py_ssize_t, Py_ssize_t, const char*, const char*, PyObject* (*)(const char*, Py_ssize_t, const char*))’:
#       sklearn/cluster/_hierarchical.cpp:24686:45: warning: ‘PyObject* PyUnicode_FromUnicode(const Py_UNICODE*, Py_ssize_t)’ is deprecated [-Wdeprecated-declarations]
#                return PyUnicode_FromUnicode(NULL, 0);
#                                                    ^
#       In file included from /opt/conda/envs/Python-RT23.1/include/python3.10/unicodeobject.h:1046,
#                        from /opt/conda/envs/Python-RT23.1/include/python3.10/Python.h:83,
#                        from sklearn/cluster/_hierarchical.cpp:22:
#       /opt/conda/envs/Python-RT23.1/include/python3.10/cpython/unicodeobject.h:551:42: note: declared here
#        Py_DEPRECATED(3.3) PyAPI_FUNC(PyObject*) PyUnicode_FromUnicode(
#                                                 ^~~~~~~~~~~~~~~~~~~~~
#       sklearn/cluster/_hierarchical.cpp:24686:45: warning: ‘PyObject* PyUnicode_FromUnicode(const Py_UNICODE*, Py_ssize_t)’ is deprecated [-Wdeprecated-declarations]
#                return PyUnicode_FromUnicode(NULL, 0);
#                                                    ^
#       In file included from /opt/conda/envs/Python-RT23.1/include/python3.10/unicodeobject.h:1046,
#                        from /opt/conda/envs/Python-RT23.1/include/python3.10/Python.h:83,
#                        from sklearn/cluster/_hierarchical.cpp:22:
#       /opt/conda/envs/Python-RT23.1/include/python3.10/cpython/unicodeobject.h:551:42: note: declared here
#        Py_DEPRECATED(3.3) PyAPI_FUNC(PyObject*) PyUnicode_FromUnicode(
#                                                 ^~~~~~~~~~~~~~~~~~~~~
#       sklearn/cluster/_hierarchical.cpp: In function ‘void __Pyx_ExceptionSave(PyObject**, PyObject**, PyObject**)’:
#       sklearn/cluster/_hierarchical.cpp:24698:21: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_type’; did you mean ‘curexc_type’?
#            *type = tstate->exc_type;
#                            ^~~~~~~~
#                            curexc_type
#       sklearn/cluster/_hierarchical.cpp:24699:22: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_value’; did you mean ‘curexc_value’?
#            *value = tstate->exc_value;
#                             ^~~~~~~~~
#                             curexc_value
#       sklearn/cluster/_hierarchical.cpp:24700:19: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#            *tb = tstate->exc_traceback;
#                          ^~~~~~~~~~~~~
#                          curexc_traceback
#       sklearn/cluster/_hierarchical.cpp: In function ‘void __Pyx_ExceptionReset(PyObject*, PyObject*, PyObject*)’:
#       sklearn/cluster/_hierarchical.cpp:24712:24: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_type’; did you mean ‘curexc_type’?
#            tmp_type = tstate->exc_type;
#                               ^~~~~~~~
#                               curexc_type
#       sklearn/cluster/_hierarchical.cpp:24713:25: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_value’; did you mean ‘curexc_value’?
#            tmp_value = tstate->exc_value;
#                                ^~~~~~~~~
#                                curexc_value
#       sklearn/cluster/_hierarchical.cpp:24714:22: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#            tmp_tb = tstate->exc_traceback;
#                             ^~~~~~~~~~~~~
#                             curexc_traceback
#       sklearn/cluster/_hierarchical.cpp:24715:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_type’; did you mean ‘curexc_type’?
#            tstate->exc_type = type;
#                    ^~~~~~~~
#                    curexc_type
#       sklearn/cluster/_hierarchical.cpp:24716:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_value’; did you mean ‘curexc_value’?
#            tstate->exc_value = value;
#                    ^~~~~~~~~
#                    curexc_value
#       sklearn/cluster/_hierarchical.cpp:24717:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#            tstate->exc_traceback = tb;
#                    ^~~~~~~~~~~~~
#                    curexc_traceback
#       sklearn/cluster/_hierarchical.cpp: In function ‘int __Pyx_GetException(PyObject**, PyObject**, PyObject**)’:
#       sklearn/cluster/_hierarchical.cpp:24760:24: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_type’; did you mean ‘curexc_type’?
#            tmp_type = tstate->exc_type;
#                               ^~~~~~~~
#                               curexc_type
#       sklearn/cluster/_hierarchical.cpp:24761:25: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_value’; did you mean ‘curexc_value’?
#            tmp_value = tstate->exc_value;
#                                ^~~~~~~~~
#                                curexc_value
#       sklearn/cluster/_hierarchical.cpp:24762:22: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#            tmp_tb = tstate->exc_traceback;
#                             ^~~~~~~~~~~~~
#                             curexc_traceback
#       sklearn/cluster/_hierarchical.cpp:24763:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_type’; did you mean ‘curexc_type’?
#            tstate->exc_type = local_type;
#                    ^~~~~~~~
#                    curexc_type
#       sklearn/cluster/_hierarchical.cpp:24764:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_value’; did you mean ‘curexc_value’?
#            tstate->exc_value = local_value;
#                    ^~~~~~~~~
#                    curexc_value
#       sklearn/cluster/_hierarchical.cpp:24765:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#            tstate->exc_traceback = local_tb;
#                    ^~~~~~~~~~~~~
#                    curexc_traceback
#       sklearn/cluster/_hierarchical.cpp: In function ‘void __Pyx_ExceptionSwap(PyObject**, PyObject**, PyObject**)’:
#       sklearn/cluster/_hierarchical.cpp:24787:24: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_type’; did you mean ‘curexc_type’?
#            tmp_type = tstate->exc_type;
#                               ^~~~~~~~
#                               curexc_type
#       sklearn/cluster/_hierarchical.cpp:24788:25: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_value’; did you mean ‘curexc_value’?
#            tmp_value = tstate->exc_value;
#                                ^~~~~~~~~
#                                curexc_value
#       sklearn/cluster/_hierarchical.cpp:24789:22: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#            tmp_tb = tstate->exc_traceback;
#                             ^~~~~~~~~~~~~
#                             curexc_traceback
#       sklearn/cluster/_hierarchical.cpp:24790:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_type’; did you mean ‘curexc_type’?
#            tstate->exc_type = *type;
#                    ^~~~~~~~
#                    curexc_type
#       sklearn/cluster/_hierarchical.cpp:24791:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_value’; did you mean ‘curexc_value’?
#            tstate->exc_value = *value;
#                    ^~~~~~~~~
#                    curexc_value
#       sklearn/cluster/_hierarchical.cpp:24792:13: error: ‘PyThreadState’ {aka ‘struct _ts’} has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#            tstate->exc_traceback = *tb;
#                    ^~~~~~~~~~~~~
#                    curexc_traceback
#       error: Command "g++ -pthread -B /opt/conda/envs/Python-RT23.1/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/envs/Python-RT23.1/include -fPIC -O2 -isystem /opt/conda/envs/Python-RT23.1/include -fPIC -I/opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages/numpy/core/include -I/opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages/numpy/core/include -Ibuild/src.linux-x86_64-3.10/numpy/distutils/include -I/opt/conda/envs/Python-RT23.1/include/python3.10 -c sklearn/cluster/_hierarchical.cpp -o build/temp.linux-x86_64-cpython-310/sklearn/cluster/_hierarchical.o -MMD -MF build/temp.linux-x86_64-cpython-310/sklearn/cluster/_hierarchical.o.d -msse -msse2 -msse3" failed with exit status 1
#       INFO:
#       ########### EXT COMPILER OPTIMIZATION ###########
#       INFO: Platform      :
#         Architecture: x64
#         Compiler    : gcc
#
#       CPU baseline  :
#         Requested   : 'min'
#         Enabled     : SSE SSE2 SSE3
#         Flags       : -msse -msse2 -msse3
#         Extra checks: none
#
#       CPU dispatch  :
#         Requested   : 'max -xop -fma4'
#         Enabled     : SSSE3 SSE41 POPCNT SSE42 AVX F16C FMA3 AVX2 AVX512F AVX512CD AVX512_KNL AVX512_KNM AVX512_SKX AVX512_CLX AVX512_CNL AVX512_ICL
#         Generated   : none
#       INFO: CCompilerOpt.cache_flush[857] : write cache to path -> /tmp/wsuser/pip-install-zm05izuo/scikit-learn_63307558bfff4e5290ccd0d82e490222/build/temp.linux-x86_64-cpython-310/ccompiler_opt_cache_ext.py
#       INFO:
#       ########### CLIB COMPILER OPTIMIZATION ###########
#       INFO: Platform      :
#         Architecture: x64
#         Compiler    : gcc
#
#       CPU baseline  :
#         Requested   : 'min'
#         Enabled     : SSE SSE2 SSE3
#         Flags       : -msse -msse2 -msse3
#         Extra checks: none
#
#       CPU dispatch  :
#         Requested   : 'max -xop -fma4'
#         Enabled     : SSSE3 SSE41 POPCNT SSE42 AVX F16C FMA3 AVX2 AVX512F AVX512CD AVX512_KNL AVX512_KNM AVX512_SKX AVX512_CLX AVX512_CNL AVX512_ICL
#         Generated   : none
#       INFO: CCompilerOpt.cache_flush[857] : write cache to path -> /tmp/wsuser/pip-install-zm05izuo/scikit-learn_63307558bfff4e5290ccd0d82e490222/build/temp.linux-x86_64-cpython-310/ccompiler_opt_cache_clib.py
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for scikit-learn
#   Running setup.py clean for scikit-learn
# Failed to build scikit-learn
# ERROR: Could not build wheels for scikit-learn, which is required to install pyproject.toml-based projects

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
filepath='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/kc_house_data_NaN.csv'
df = pd.read_csv(filepath)

# %%
mean=df['bathrooms'].mean()
df['bathrooms'].replace(np.nan,mean, inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0       3.0       1.00
# 1           1  6414100192  20141209T000000  538000.0       3.0       2.25
# 2           2  5631500400  20150225T000000  180000.0       2.0       1.00
# 3           3  2487200875  20141209T000000  604000.0       4.0       3.00
# 4           4  1954400510  20150218T000000  510000.0       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 0         1180      5650     1.0           0     0          3      7
# 1         2570      7242     2.0           0     0          3      7
# 2          770     10000     1.0           0     0          3      6
# 3         1960      5000     1.0           0     0          5      7
# 4         1680      8080     1.0           0     0          3      8
#
#    sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0        1180              0      1955             0    98178  47.5112
# 1        2170            400      1951          1991    98125  47.7210
# 2         770              0      1933             0    98028  47.7379
# 3        1050            910      1965             0    98136  47.5208
# 4        1680              0      1987             0    98074  47.6168
#
#       long  sqft_living15  sqft_lot15
# 0 -122.257           1340        5650
# 1 -122.319           1690        7639
# 2 -122.233           2720        8062
# 3 -122.393           1360        5000
# 4 -122.045           1800        7503

# %%
print(df.dtypes)
# Out:
# Unnamed: 0         int64
# id                 int64
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.drop("id", axis = 1, inplace = True)
df.drop("Unnamed: 0", axis = 1, inplace = True)

df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21600.000000  21603.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.372870      2.115736   2079.899736  1.510697e+04
# std    3.671272e+05      0.926657      0.768996    918.440897  4.142051e+04
# min    7.500000e+04      1.000000      0.500000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# std        0.539989      0.086517      0.766318      0.650743      1.175459
# min        1.000000      0.000000      0.000000      1.000000      1.000000
# 25%        1.000000      0.000000      0.000000      3.000000      7.000000
# 50%        1.500000      0.000000      0.000000      3.000000      7.000000
# 75%        2.000000      0.000000      0.000000      4.000000      8.000000
# max        3.500000      1.000000      4.000000      5.000000     13.000000
#
#          sqft_above  sqft_basement      yr_built  yr_renovated       zipcode  \
# count  21613.000000   21613.000000  21613.000000  21613.000000  21613.000000
# mean    1788.390691     291.509045   1971.005136     84.402258  98077.939805
# std      828.090978     442.575043     29.373411    401.679240     53.505026
# min      290.000000       0.000000   1900.000000      0.000000  98001.000000
# 25%     1190.000000       0.000000   1951.000000      0.000000  98033.000000
# 50%     1560.000000       0.000000   1975.000000      0.000000  98065.000000
# 75%     2210.000000     560.000000   1997.000000      0.000000  98118.000000
# max     9410.000000    4820.000000   2015.000000   2015.000000  98199.000000
#
#                 lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000   21613.000000   21613.000000
# mean      47.560053   -122.213896    1986.552492   12768.455652
# std        0.138564      0.140828     685.391304   27304.179631
# min       47.155900   -122.519000     399.000000     651.000000
# 25%       47.471000   -122.328000    1490.000000    5100.000000
# 50%       47.571800   -122.230000    1840.000000    7620.000000
# 75%       47.678000   -122.125000    2360.000000   10083.000000
# max       47.777600   -121.315000    6210.000000  871200.000000

# %%
df['floors'].value_counts().to_frame()
# Out:
#      floors
# 1.0   10680
# 2.0    8241
# 1.5    1910
# 3.0     613
# 2.5     161
# 3.5       8

# %%
sns.boxplot(x="waterfront",y="price",data=df)
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
sns.regplot(x="sqft_above",y="price",data=df,color='green',ci=None)
sns.regplot
# Out:
# <function seaborn.regression.regplot(data=None, *, x=None, y=None, x_estimator=None, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=95, n_boot=1000, units=None, seed=None, order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, truncate=True, dropna=True, x_jitter=None, y_jitter=None, label=None, color=None, marker='o', scatter_kws=None, line_kws=None, ax=None)>

# %%
X1 = df[['sqft_living']]
Y1 = df['price']
lm = LinearRegression()
lm
lm.fit(X1,Y1)
lm.score(X1, Y1)
# Out:
# 0.4928532179037931

# %%
features =["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]

# %%
X2 = df[features]
Y2 = df['price']
lm.fit(X2,Y2)
lm.score(X2,Y2)
# Out:
# 0.6576722447699446

# %%
Objects=[('scale',StandardScaler()),('polynomial', PolynomialFeatures(include_bias=False)),('model',LinearRegression())]
pipe=Pipeline(Objects)
pipe
X = df[features]
Y = df['price']
pipe.fit(X,Y)
pipe.score(X,Y)
# Out:
# 0.7513410648797747

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
print("done")
# Out:
# done

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.15, random_state=1)

print("number of test samples:", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples: 3242
# number of training samples: 18371

# %%
from sklearn.linear_model import Ridge
RidgeModel=Ridge(alpha=0.1)
RidgeModel.fit(x_train,y_train)
RidgeModel.score(x_train,y_train)
# Out:
# 0.659437853495024

# %%
pr = PolynomialFeatures(degree = 2)
x_train_pr = pr.fit_transform(x_train[features])
x_test_pr = pr.fit_transform(x_test[features])

RidgeModel2 = Ridge(alpha = 0.1) 
RidgeModel2.fit(x_train_pr, y_train)
RidgeModel2.score(x_test_pr, y_test)
# Out:
# 0.700274426790608
